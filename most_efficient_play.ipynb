# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulBhatt24/NFL-Projects/blob/main/most_efficient_play.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installing Packages

# %%
# !pip install nfl_data_py
# !pip install pandas
# !pip install os
# !pip install matplotlib

# %%
import nfl_data_py as nfl
import pandas as pd
import os
import urllib.request
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnnotationBbox, OffsetImage

# %% [markdown]
# # Input User Filters

# %%
team = "PHI"
yard_line = 15
side_of_field = "OPP"
down = 3

# %% [markdown]
# # Import data from 2022 season

# %%
pbp = nfl.import_pbp_data([2022])
# Out:
# 2022 done.
# Downcasting floats.

# %%
pbp.head()
# Out:
#    play_id          game_id old_game_id home_team away_team season_type  week  \
# 0      1.0  2022_01_BAL_NYJ  2022091107       NYJ       BAL         REG     1
# 1     43.0  2022_01_BAL_NYJ  2022091107       NYJ       BAL         REG     1
# 2     68.0  2022_01_BAL_NYJ  2022091107       NYJ       BAL         REG     1
# 3     89.0  2022_01_BAL_NYJ  2022091107       NYJ       BAL         REG     1
# 4    115.0  2022_01_BAL_NYJ  2022091107       NYJ       BAL         REG     1
#
#   posteam posteam_type defteam  ... offense_formation  offense_personnel  \
# 0    None         None    None  ...              None               None
# 1     NYJ         home     BAL  ...              None               None
# 2     NYJ         home     BAL  ...        SINGLEBACK   1 RB, 2 TE, 2 WR
# 3     NYJ         home     BAL  ...           SHOTGUN   1 RB, 2 TE, 2 WR
# 4     NYJ         home     BAL  ...        SINGLEBACK   1 RB, 2 TE, 2 WR
#
# ...

# %% [markdown]
# # Filter the data

# %%
pbp = pbp[(pbp['pass'] == 1) | (pbp['rush'] == 1)]
pbp = pbp[ pbp["posteam"] == team]
pbp = pbp[ pbp["yardline_100"] == yard_line]
if (side_of_field == "PHI"):
  pbp = pbp[ pbp["side_of_field"] == "PHI"]
else:
  pbp = pbp[ pbp["side_of_field"] != "PHI"]

# %%
pbp.head()
# Out:
#        play_id          game_id old_game_id home_team away_team season_type  \
# 15100   1052.0  2022_06_DAL_PHI  2022101611       PHI       DAL         REG
# 30033    451.0   2022_12_GB_PHI  2022112711       PHI        GB         REG
# 34244   3521.0  2022_13_TEN_PHI  2022120407       PHI       TEN         REG
# 49604   3079.0  2022_20_NYG_PHI  2023012101       PHI       NYG        POST
# 13392   2421.0  2022_05_PHI_ARI  2022100911       ARI       PHI         REG
#
#        week posteam posteam_type defteam  ... offense_formation  \
# 15100     6     PHI         home     DAL  ...           SHOTGUN
# 30033    12     PHI         home      GB  ...           SHOTGUN
# 34244    13     PHI         home     TEN  ...             JUMBO
# 49604    20     PHI         home     NYG  ...           SHOTGUN
# 13392     5     PHI         away     ARI  ...           SHOTGUN
#
#        offense_personnel defenders_in_box  defense_personnel  \
# ...

# %% [markdown]
# # **Results**

# %%
pbp = pbp.sort_values("epa", ascending=False)
pbp[["posteam", "offense_formation", "play_type", "epa"]]
# Out:
#       posteam offense_formation play_type       epa
# 15100     PHI           SHOTGUN      pass  2.797051
# 30033     PHI           SHOTGUN       run  1.839226
# 34244     PHI             JUMBO       run  1.423472
# 49604     PHI           SHOTGUN       run -0.444981
# 13392     PHI           SHOTGUN   no_play -1.142443
